# %%
import os

def rename_files(directory):
    # List all files in the directory
    files = os.listdir(directory)
    
    # Filter out files that do not match the pattern x.csv
    csv_files = [f for f in files if f.endswith('.csv') and f[:-4].isdigit()]
    
    # Sort files by their numerical part
    csv_files.sort(key=lambda x: int(x[:-4]))
    
    # Rename files in the specified order
    for idx, old_name in enumerate(csv_files):
        new_name = f'archive_{idx}.csv'
        old_path = os.path.join(directory, old_name)
        new_path = os.path.join(directory, new_name)
        os.rename(old_path, new_path)
        print(f'Renamed {old_name} to {new_name}')

# Specify the directory containing the CSV files
directory = 'archive_logs120Hurst_grouped/tmp'

# Call the rename function
rename_files(directory)
# Out:
# Renamed 0.csv to archive_0.csv
# Renamed 100.csv to archive_1.csv
# Renamed 600.csv to archive_2.csv
# Renamed 1100.csv to archive_3.csv
# Renamed 1600.csv to archive_4.csv
# Renamed 2100.csv to archive_5.csv
# Renamed 2600.csv to archive_6.csv
# Renamed 3100.csv to archive_7.csv
# Renamed 3600.csv to archive_8.csv
# Renamed 4100.csv to archive_9.csv
# Renamed 4600.csv to archive_10.csv
# Renamed 5100.csv to archive_11.csv
# Renamed 5600.csv to archive_12.csv
# Renamed 6100.csv to archive_13.csv
# Renamed 6600.csv to archive_14.csv
# Renamed 7100.csv to archive_15.csv
# Renamed 7600.csv to archive_16.csv
# Renamed 8100.csv to archive_17.csv
# Renamed 8600.csv to archive_18.csv
# Renamed 9100.csv to archive_19.csv
# Renamed 9600.csv to archive_20.csv
# Renamed 10135.csv to archive_21.csv
# Renamed 10639.csv to archive_22.csv
# Renamed 11143.csv to archive_23.csv
# Renamed 11647.csv to archive_24.csv
# Renamed 12151.csv to archive_25.csv
# Renamed 12655.csv to archive_26.csv
# Renamed 13159.csv to archive_27.csv
# Renamed 13663.csv to archive_28.csv
# Renamed 14167.csv to archive_29.csv
# Renamed 14671.csv to archive_30.csv
# Renamed 15175.csv to archive_31.csv
# Renamed 15679.csv to archive_32.csv
# Renamed 16183.csv to archive_33.csv
# Renamed 16687.csv to archive_34.csv
# Renamed 17191.csv to archive_35.csv
# Renamed 17754.csv to archive_36.csv
# Renamed 18298.csv to archive_37.csv
# Renamed 18842.csv to archive_38.csv
# Renamed 19386.csv to archive_39.csv
# Renamed 19930.csv to archive_40.csv
# Renamed 20474.csv to archive_41.csv
# Renamed 21018.csv to archive_42.csv
# Renamed 21562.csv to archive_43.csv
# Renamed 22106.csv to archive_44.csv
# Renamed 22650.csv to archive_45.csv
# Renamed 23194.csv to archive_46.csv
# Renamed 23738.csv to archive_47.csv
# Renamed 24282.csv to archive_48.csv
# Renamed 24826.csv to archive_49.csv
# Renamed 25370.csv to archive_50.csv
# Renamed 25914.csv to archive_51.csv
# Renamed 26458.csv to archive_52.csv
# Renamed 27002.csv to archive_53.csv
# Renamed 27546.csv to archive_54.csv
# Renamed 28090.csv to archive_55.csv
# Renamed 28634.csv to archive_56.csv
# Renamed 29178.csv to archive_57.csv
# Renamed 29722.csv to archive_58.csv
# Renamed 30266.csv to archive_59.csv
# Renamed 30810.csv to archive_60.csv
# Renamed 31354.csv to archive_61.csv
# Renamed 31898.csv to archive_62.csv
# Renamed 32442.csv to archive_63.csv
# Renamed 32986.csv to archive_64.csv
# Renamed 33530.csv to archive_65.csv
# Renamed 34074.csv to archive_66.csv
# Renamed 34618.csv to archive_67.csv
# Renamed 35162.csv to archive_68.csv
# Renamed 35706.csv to archive_69.csv
# Renamed 36250.csv to archive_70.csv
# Renamed 36794.csv to archive_71.csv
# Renamed 37338.csv to archive_72.csv
# Renamed 37882.csv to archive_73.csv
# Renamed 38426.csv to archive_74.csv
# Renamed 38970.csv to archive_75.csv
# Renamed 39514.csv to archive_76.csv
# Renamed 40058.csv to archive_77.csv
# Renamed 40602.csv to archive_78.csv
# Renamed 41146.csv to archive_79.csv
# Renamed 41690.csv to archive_80.csv
# Renamed 42234.csv to archive_81.csv
# Renamed 42778.csv to archive_82.csv
# Renamed 43322.csv to archive_83.csv
# Renamed 43866.csv to archive_84.csv
# Renamed 44410.csv to archive_85.csv
# Renamed 44954.csv to archive_86.csv
# Renamed 45498.csv to archive_87.csv
# Renamed 46042.csv to archive_88.csv
# Renamed 46586.csv to archive_89.csv
# Renamed 47130.csv to archive_90.csv
# Renamed 47674.csv to archive_91.csv
# Renamed 48218.csv to archive_92.csv
# Renamed 48762.csv to archive_93.csv
# Renamed 49306.csv to archive_94.csv
# Renamed 49850.csv to archive_95.csv
# Renamed 50394.csv to archive_96.csv
# Renamed 50938.csv to archive_97.csv
# Renamed 51482.csv to archive_98.csv
# Renamed 52026.csv to archive_99.csv
# Renamed 52570.csv to archive_100.csv
# Renamed 53114.csv to archive_101.csv
# Renamed 53658.csv to archive_102.csv
# Renamed 54202.csv to archive_103.csv
# Renamed 54746.csv to archive_104.csv
# Renamed 55290.csv to archive_105.csv
# Renamed 55834.csv to archive_106.csv
# Renamed 56378.csv to archive_107.csv
# Renamed 56922.csv to archive_108.csv
# Renamed 57466.csv to archive_109.csv
# Renamed 58010.csv to archive_110.csv
# Renamed 58554.csv to archive_111.csv
# Renamed 59098.csv to archive_112.csv
# Renamed 59642.csv to archive_113.csv
# Renamed 60186.csv to archive_114.csv
# Renamed 60730.csv to archive_115.csv
# Renamed 61274.csv to archive_116.csv
# Renamed 61818.csv to archive_117.csv
# Renamed 62362.csv to archive_118.csv
# Renamed 62906.csv to archive_119.csv
# Renamed 63450.csv to archive_120.csv
# Renamed 63994.csv to archive_121.csv
# Renamed 64538.csv to archive_122.csv
# Renamed 65082.csv to archive_123.csv
# Renamed 65626.csv to archive_124.csv
# Renamed 66170.csv to archive_125.csv
# Renamed 66714.csv to archive_126.csv
# Renamed 67258.csv to archive_127.csv
# Renamed 67802.csv to archive_128.csv
# Renamed 68346.csv to archive_129.csv
# Renamed 68890.csv to archive_130.csv
# Renamed 69434.csv to archive_131.csv
# Renamed 69978.csv to archive_132.csv
# Renamed 70046.csv to archive_133.csv
