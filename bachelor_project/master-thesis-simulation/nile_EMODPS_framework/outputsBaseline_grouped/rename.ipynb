# %%
import os

def rename_files(directory):
    # List all files in the directory
    files = os.listdir(directory)
    
    # Filter out files that do not match the pattern x.csv
    csv_files = [f for f in files if f.endswith('.csv') and f[:-4].isdigit()]
    
    # Sort files by their numerical part
    csv_files.sort(key=lambda x: int(x[:-4]))
    
    # Rename files in the specified order
    for idx, old_name in enumerate(csv_files):
        new_name = f'archive_{idx}.csv'
        old_path = os.path.join(directory, old_name)
        new_path = os.path.join(directory, new_name)
        os.rename(old_path, new_path)
        print(f'Renamed {old_name} to {new_name}')

# Specify the directory containing the CSV files
directory = 'archive_logsBaseline_grouped/tmp'

# Call the rename function
rename_files(directory)
# Out:
# Renamed 0.csv to archive_0.csv
# Renamed 100.csv to archive_1.csv
# Renamed 600.csv to archive_2.csv
# Renamed 1100.csv to archive_3.csv
# Renamed 1600.csv to archive_4.csv
# Renamed 2100.csv to archive_5.csv
# Renamed 2600.csv to archive_6.csv
# Renamed 3100.csv to archive_7.csv
# Renamed 3600.csv to archive_8.csv
# Renamed 4100.csv to archive_9.csv
# Renamed 4600.csv to archive_10.csv
# Renamed 5100.csv to archive_11.csv
# Renamed 5600.csv to archive_12.csv
# Renamed 6100.csv to archive_13.csv
# Renamed 6600.csv to archive_14.csv
# Renamed 7100.csv to archive_15.csv
# Renamed 7600.csv to archive_16.csv
# Renamed 8100.csv to archive_17.csv
# Renamed 8600.csv to archive_18.csv
# Renamed 9100.csv to archive_19.csv
# Renamed 9600.csv to archive_20.csv
# Renamed 10100.csv to archive_21.csv
# Renamed 10600.csv to archive_22.csv
# Renamed 11100.csv to archive_23.csv
# Renamed 11600.csv to archive_24.csv
# Renamed 12100.csv to archive_25.csv
# Renamed 12600.csv to archive_26.csv
# Renamed 13100.csv to archive_27.csv
# Renamed 13600.csv to archive_28.csv
# Renamed 14100.csv to archive_29.csv
# Renamed 14600.csv to archive_30.csv
# Renamed 15100.csv to archive_31.csv
# Renamed 15600.csv to archive_32.csv
# Renamed 16100.csv to archive_33.csv
# Renamed 16600.csv to archive_34.csv
# Renamed 17100.csv to archive_35.csv
# Renamed 17600.csv to archive_36.csv
# Renamed 18100.csv to archive_37.csv
# Renamed 18600.csv to archive_38.csv
# Renamed 19100.csv to archive_39.csv
# Renamed 19600.csv to archive_40.csv
# Renamed 20105.csv to archive_41.csv
# Renamed 20645.csv to archive_42.csv
# Renamed 21185.csv to archive_43.csv
# Renamed 21725.csv to archive_44.csv
# Renamed 22265.csv to archive_45.csv
# Renamed 22805.csv to archive_46.csv
# Renamed 23345.csv to archive_47.csv
# Renamed 23885.csv to archive_48.csv
# Renamed 24425.csv to archive_49.csv
# Renamed 24965.csv to archive_50.csv
# Renamed 25505.csv to archive_51.csv
# Renamed 26045.csv to archive_52.csv
# Renamed 26585.csv to archive_53.csv
# Renamed 27125.csv to archive_54.csv
# Renamed 27665.csv to archive_55.csv
# Renamed 28205.csv to archive_56.csv
# Renamed 28745.csv to archive_57.csv
# Renamed 29285.csv to archive_58.csv
# Renamed 29825.csv to archive_59.csv
# Renamed 30365.csv to archive_60.csv
# Renamed 30905.csv to archive_61.csv
# Renamed 31445.csv to archive_62.csv
# Renamed 31985.csv to archive_63.csv
# Renamed 32525.csv to archive_64.csv
# Renamed 33065.csv to archive_65.csv
# Renamed 33605.csv to archive_66.csv
# Renamed 34145.csv to archive_67.csv
# Renamed 34685.csv to archive_68.csv
# Renamed 35225.csv to archive_69.csv
# Renamed 35765.csv to archive_70.csv
# Renamed 36305.csv to archive_71.csv
# Renamed 36845.csv to archive_72.csv
# Renamed 37385.csv to archive_73.csv
# Renamed 37925.csv to archive_74.csv
# Renamed 38465.csv to archive_75.csv
# Renamed 39005.csv to archive_76.csv
# Renamed 39545.csv to archive_77.csv
# Renamed 40085.csv to archive_78.csv
# Renamed 40625.csv to archive_79.csv
# Renamed 41165.csv to archive_80.csv
# Renamed 41705.csv to archive_81.csv
# Renamed 42245.csv to archive_82.csv
# Renamed 42785.csv to archive_83.csv
# Renamed 43325.csv to archive_84.csv
# Renamed 43865.csv to archive_85.csv
# Renamed 44405.csv to archive_86.csv
# Renamed 44945.csv to archive_87.csv
# Renamed 45485.csv to archive_88.csv
# Renamed 46025.csv to archive_89.csv
# Renamed 46565.csv to archive_90.csv
# Renamed 47105.csv to archive_91.csv
# Renamed 47645.csv to archive_92.csv
# Renamed 48185.csv to archive_93.csv
# Renamed 48725.csv to archive_94.csv
# Renamed 49265.csv to archive_95.csv
# Renamed 49805.csv to archive_96.csv
# Renamed 50345.csv to archive_97.csv
# Renamed 50885.csv to archive_98.csv
# Renamed 51425.csv to archive_99.csv
# Renamed 51965.csv to archive_100.csv
# Renamed 52505.csv to archive_101.csv
# Renamed 53045.csv to archive_102.csv
# Renamed 53585.csv to archive_103.csv
# Renamed 54125.csv to archive_104.csv
# Renamed 54665.csv to archive_105.csv
# Renamed 55205.csv to archive_106.csv
# Renamed 55745.csv to archive_107.csv
# Renamed 56285.csv to archive_108.csv
# Renamed 56825.csv to archive_109.csv
# Renamed 57365.csv to archive_110.csv
# Renamed 57905.csv to archive_111.csv
# Renamed 58445.csv to archive_112.csv
# Renamed 58985.csv to archive_113.csv
# Renamed 59525.csv to archive_114.csv
# Renamed 60065.csv to archive_115.csv
# Renamed 60605.csv to archive_116.csv
# Renamed 61145.csv to archive_117.csv
# Renamed 61685.csv to archive_118.csv
# Renamed 62192.csv to archive_119.csv
# Renamed 62696.csv to archive_120.csv
# Renamed 63200.csv to archive_121.csv
# Renamed 63704.csv to archive_122.csv
# Renamed 64208.csv to archive_123.csv
# Renamed 64712.csv to archive_124.csv
# Renamed 65216.csv to archive_125.csv
# Renamed 65720.csv to archive_126.csv
# Renamed 66224.csv to archive_127.csv
# Renamed 66728.csv to archive_128.csv
# Renamed 67232.csv to archive_129.csv
# Renamed 67736.csv to archive_130.csv
# Renamed 68240.csv to archive_131.csv
# Renamed 68744.csv to archive_132.csv
# Renamed 69248.csv to archive_133.csv
# Renamed 69752.csv to archive_134.csv
# Renamed 70004.csv to archive_135.csv
